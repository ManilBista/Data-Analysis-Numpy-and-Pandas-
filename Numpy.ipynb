# %%
# CREATE  LIST OF 10,00,000 SALARIES RANGING FROM 50000 T0 1500000

# %%
import random
import statistics

# %%
salary_list = np.random.randint(50000, 150001, size=1_000_000)

# %%
salary_list[random.randint(0, len(salary_list) - 1)]
# Out:
# np.int64(92760)

# %%
import numpy as np

# %%
# %%timeit
np.mean(salary_list)
# Out:
# 819 µs ± 29.5 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %%timeit
np.median(salary_list)
# Out:
# 11.4 ms ± 380 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
my_array= np.array([1,2,3,4,5,6])

# %%
my_array.mean()
# Out:
# np.float64(3.5)

# %%
#job titles
job_titles=np.array(['Data Analyst','Data Scientist','Data Engineer','ML Engineer','AI Engineer'])

#Base salaries
base_salaries=np.array([60000,80000,75000,90000,np.nan])

#bonus rates
bonus_rates= np.array([.05,.1,.08,.12, np.nan])

# %%
total_salaries=base_salaries+(base_salaries*bonus_rates)

# %%
total_salaries=base_salaries*(1+bonus_rates)
total_salaries
# Out:
# array([ 63000.,  88000.,  81000., 100800.,     nan])

# %%
np.mean(total_salaries)
# Out:
# np.float64(nan)

# %%
np.nanmean(total_salaries)
# Out:
# np.float64(83200.0)
